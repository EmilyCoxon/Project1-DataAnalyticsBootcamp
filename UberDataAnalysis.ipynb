# %%
import pandas as pd

# %%
# The path to our CSV file
csv_path = "Resources/uber.csv"
uberdata_master_df= pd.read_csv(csv_path,encoding="utf-8")
uberdata_master_df.head(100)
# Out:
#     Unnamed: 0                            key  fare_amount  \
# 0     24238194    2015-05-07 19:52:06.0000003          7.5
# 1     27835199    2009-07-17 20:04:56.0000002          7.7
# 2     44984355   2009-08-24 21:45:00.00000061         12.9
# 3     25894730    2009-06-26 08:22:21.0000001          5.3
# 4     17610152  2014-08-28 17:47:00.000000188         16.0
# ..         ...                            ...          ...
# 95    25431833    2015-04-11 08:47:47.0000001          9.5
# 96    44792012  2011-10-03 20:29:00.000000179          4.5
# 97    18571020    2010-04-26 03:12:44.0000001          3.3
# 98    37942404  2011-11-18 09:51:00.000000166         30.9
# 99    29024472    2009-08-30 14:03:55.0000002         26.9
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0   2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1   2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2   2009-08-24 21:45:00 UTC        -74.005043        40.740770
# ...

# %%
uberdata_master_df.dtypes
# Out:
# Unnamed: 0             int64
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
#This gives total count
uberdata_master_df.count()
# Out:
# Unnamed: 0           200000
# key                  200000
# fare_amount          200000
# pickup_datetime      200000
# pickup_longitude     200000
# pickup_latitude      200000
# dropoff_longitude    199999
# dropoff_latitude     199999
# passenger_count      200000
# dtype: int64

# %%
#This give ifnull count 
uberdata_master_df.isna().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
#Dropping null 
uberdata_clean_df = uberdata_master_df.dropna(how='any')
uberdata_clean_df.count()
# Out:
# Unnamed: 0           199999
# key                  199999
# fare_amount          199999
# pickup_datetime      199999
# pickup_longitude     199999
# pickup_latitude      199999
# dropoff_longitude    199999
# dropoff_latitude     199999
# passenger_count      199999
# dtype: int64

# %%
uberdata_clean_df.head(100)
# Out:
#     Unnamed: 0                            key  fare_amount  \
# 0     24238194    2015-05-07 19:52:06.0000003          7.5
# 1     27835199    2009-07-17 20:04:56.0000002          7.7
# 2     44984355   2009-08-24 21:45:00.00000061         12.9
# 3     25894730    2009-06-26 08:22:21.0000001          5.3
# 4     17610152  2014-08-28 17:47:00.000000188         16.0
# ..         ...                            ...          ...
# 95    25431833    2015-04-11 08:47:47.0000001          9.5
# 96    44792012  2011-10-03 20:29:00.000000179          4.5
# 97    18571020    2010-04-26 03:12:44.0000001          3.3
# 98    37942404  2011-11-18 09:51:00.000000166         30.9
# 99    29024472    2009-08-30 14:03:55.0000002         26.9
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0   2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1   2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2   2009-08-24 21:45:00 UTC        -74.005043        40.740770
# ...

# %%
#uberdata_time_df=[['pickupdate','pickuptime','timezone']]
#uberdata_time_df

#uberdata_time_df = {
#    'pickupdate':[],
#    'pickuptime':[],
#    'timezone':[]
#    }
#uberdata_datetime_df = uberdata_clean_df + uberdata_time_df
#uberdata_datetime_df = uberdata_clean_df.pickup_datetime.str.split(" ", expand = True)



#uberdata_clean_df['pickupdate'] = " "
#uberdata_clean_df['pickuptime'] = " "
#uberdata_clean_df['timezone']= " " 

#uberdata_clean_df.head()

###########################

uberdata_time_df = {
    'pickupdate':[],
    'pickuptime':[],
    'timezone':[],
    'pickup_datetime':uberdata_clean_df['pickup_datetime']
    }
#uberdata_time_df
uberdata_time_df=uberdata_clean_df.pickup_datetime.str.split(" ", expand = True)

uberdata_time_df

#uberdata_merged_df = pd.merge(uberdata_clean_df, uberdata_time_df, on="pickup_datetime", how="outer")
#uberdata_merged_df
# Out:
#                  0         1    2
# 0       2015-05-07  19:52:06  UTC
# 1       2009-07-17  20:04:56  UTC
# 2       2009-08-24  21:45:00  UTC
# 3       2009-06-26  08:22:21  UTC
# 4       2014-08-28  17:47:00  UTC
# ...            ...       ...  ...
# 199995  2012-10-28  10:49:00  UTC
# 199996  2014-03-14  01:09:00  UTC
# 199997  2009-06-29  00:42:00  UTC
# 199998  2015-05-20  14:56:25  UTC
# 199999  2010-05-15  04:08:00  UTC
#
# [199999 rows x 3 columns]

# %%
# Calculate the total number of backers for all Australian projects

# %%
# Calculate the average number of backers for all Australian projects

# %%
# Collect only those Australian campaigns that were featured in the spotlight

# %%
# Group by the outcome of the campaigns and see if a spotlight matters
